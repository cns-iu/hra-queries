# %% [markdown]
# ## A notebook to get metadata for a SenNet donor

# %%
# Install packages
# %pip install requests hra_jupyter_widgets ipywidgets
# Out:
# Requirement already satisfied: requests in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (2.32.3)
# Requirement already satisfied: hra_jupyter_widgets in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (0.4.0)
# Requirement already satisfied: ipywidgets in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (8.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: anywidget in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from hra_jupyter_widgets) (0.9.13)
# Requirement already satisfied: traitlets>=5.10 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from hra_jupyter_widgets) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from ipywidgets) (8.28.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: colorama in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: psygnal>=0.8.1 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from anywidget->hra_jupyter_widgets) (0.11.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from anywidget->hra_jupyter_widgets) (4.12.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\abueckle\documents\github\hra-queries\.venv\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import packages
import requests
from pprint import pprint
import ipywidgets as widgets
from hra_jupyter_widgets import (
    BodyUi,               # CCF 3D Body UI
    Eui,                  # Exploration User Interface (EUI)
    Rui,                  # Registration User Interface (RUI)
)

# %%
# set the API endpoint
entity = "https://entity.api.sennetconsortium.org/entities/"
ancestors = "https://entity.api.sennetconsortium.org/ancestors/"


# set the lab ID
lab_sample_id = "CU033-U54-HRA-058-B"
snt_donor_id = "SNT239.DNSH.749"
snt_sample_ids = ["SNT326.PVLT.534","SNT686.CXXH.355"]

# %%
# define functions
def call_entity_api(api:str,id:str):
  """Call the SenNEt Entity API with a Entity ID

  Args:
      id (str): A SenNet Entity ID
  
  Returns:
      response (dict): The API response (json)
  """

  # set headers for request
  headers = {"Authorization": "Bearer AgGBeXqmVNrv290OpDjXNXXDrNwvnoM5odKvB5OdmP94Yo4oBPs7C1gMGnylkOv75XKvy9Mq6dDrnys9q99mJFkpN7W"}

  # get API response for id
  response = requests.get(url = entity+id, headers=headers).json()
  return response

# %%
# get metadata for donor
donor = call_entity_api(entity,snt_donor_id)
pprint(donor)
# Out:
# {'created_by_user_displayname': 'Ivy Kosater',
#  'created_by_user_email': 'imk2130@cumc.columbia.edu',
#  'created_by_user_sub': '7124a15e-2abf-4fb1-9ade-fc20f879ddf7',
#  'created_timestamp': 1684247200541,
#  'data_access_level': 'consortium',
#  'entity_type': 'Source',
#  'group_name': 'TMC - Columbia University',
#  'group_uuid': '5ed4e70f-ee72-11ec-8b17-9fe9b51132b1',
#  'lab_source_id': 'U54-HRA-058',
#  'last_modified_timestamp': 1684247200541,
#  'last_modified_user_displayname': 'Ivy Kosater',
#  'last_modified_user_email': 'imk2130@cumc.columbia.edu',
#  'last_modified_user_sub': '7124a15e-2abf-4fb1-9ade-fc20f879ddf7',
#  'protocol_url': 'dx.doi.org/10.17504/protocols.io.3byl4j398lo5/v1',
#  'sennet_id': 'SNT239.DNSH.749',
#  'source_type': 'Human',
#  'uuid': '656faf3100daa4079d6bb2737fa312c6'}

# %%
# get metadata for samples
samples = [call_entity_api(entity,id) for id in snt_sample_ids]

for i in samples:
  pprint(i)
# Out:
# {'created_by_user_displayname': 'Ivy Kosater',
#  'created_by_user_email': 'imk2130@cumc.columbia.edu',
#  'created_by_user_sub': '7124a15e-2abf-4fb1-9ade-fc20f879ddf7',
#  'created_timestamp': 1685552503564,
#  'data_access_level': 'consortium',
#  'direct_ancestor': {'created_by_user_displayname': 'Ivy Kosater',
#                      'created_by_user_email': 'imk2130@cumc.columbia.edu',
#                      'created_by_user_sub': '7124a15e-2abf-4fb1-9ade-fc20f879ddf7',
#                      'created_timestamp': 1685470437534,
#                      'data_access_level': 'consortium',
#                      'description': 'N/A',
#                      'entity_type': 'Sample',
#                      'group_name': 'TMC - Columbia University',
#                      'group_uuid': '5ed4e70f-ee72-11ec-8b17-9fe9b51132b1',
#                      'lab_tissue_sample_id': 'U54-HRA-058',
#                      'last_modified_timestamp': 1685470437534,
#                      'last_modified_user_displayname': 'Ivy Kosater',
#                      'last_modified_user_email': 'imk2130@cumc.columbia.edu',
#                      'last_modified_user_sub': '7124a15e-2abf-4fb1-9ade-fc20f879ddf7',
#                      'organ': 'BR',
#                      'sample_category': 'Organ',
#                      'sennet_id': 'SNT686.CXXH.355',
#                      'source': {'created_by_user_displayname': 'Ivy Kosater',
#                                 'created_by_user_email': 'imk2130@cumc.columbia.edu',
#                                 'created_by_user_sub': '7124a15e-2abf-4fb1-9ade-fc20f879ddf7',
#                                 'created_timestamp': 1684247200541,
#                                 'data_access_level': 'consortium',
#                                 'description': '',
#                                 'entity_type': 'Source',
#                                 'group_name': 'TMC - Columbia University',
#                                 'group_uuid': '5ed4e70f-ee72-11ec-8b17-9fe9b51132b1',
#                                 'lab_source_id': 'U54-HRA-058',
#                                 'last_modified_timestamp': 1684247200541,
#                                 'last_modified_user_displayname': 'Ivy Kosater',
#                                 'last_modified_user_email': 'imk2130@cumc.columbia.edu',
#                                 'last_modified_user_sub': '7124a15e-2abf-4fb1-9ade-fc20f879ddf7',
#                                 'sennet_id': 'SNT239.DNSH.749',
#                                 'source_type': 'Human',
#                                 'uuid': '656faf3100daa4079d6bb2737fa312c6'},
#                      'uuid': '87f690b8368e8dbfc4ed436adb1c71a9'},
#  'entity_type': 'Sample',
#  'group_name': 'TMC - Columbia University',
#  'group_uuid': '5ed4e70f-ee72-11ec-8b17-9fe9b51132b1',
#  'lab_tissue_sample_id': 'U54-HRA-058',
#  'last_modified_timestamp': 1712596442222,
#  'last_modified_user_displayname': 'Courteney Mattison',
#  'last_modified_user_email': 'csm2234@cumc.columbia.edu',
#  'last_modified_user_sub': '140b15be-c4ca-4685-a888-07c0d39fecf8',
#  'protocol_url': 'dx.doi.org/10.17504/protocols.io.3byl4j398lo5',
#  'rui_location': {'@context': 'https://hubmapconsortium.github.io/ccf-ontology/ccf-context.jsonld',
#                   '@id': 'http://purl.org/ccf/1.5/e4a5c9bd-d9b2-4f63-92b1-820bfc1c01d2',
#                   '@type': 'SpatialEntity',
#                   'ccf_annotations': ['http://purl.obolibrary.org/obo/UBERON_0002702'],
#                   'creation_date': '2024-04-08',
#                   'creator': 'Courteney Mattison',
#                   'creator_first_name': 'Courteney',
#                   'creator_last_name': 'Mattison',
#                   'dimension_units': 'millimeter',
#                   'placement': {'@context': 'https://hubmapconsortium.github.io/ccf-ontology/ccf-context.jsonld',
#                                 '@id': 'http://purl.org/ccf/1.5/e4a5c9bd-d9b2-4f63-92b1-820bfc1c01d2_placement',
#                                 '@type': 'SpatialPlacement',
#                                 'placement_date': '2024-04-08',
#                                 'rotation_order': 'XYZ',
#                                 'rotation_units': 'degree',
#                                 'scaling_units': 'ratio',
#                                 'target': 'http://purl.org/ccf/latest/ccf.owl#VHMAllenBrain',
#                                 'translation_units': 'millimeter',
#                                 'x_rotation': 0,
#                                 'x_scaling': 1,
#                                 'x_translation': 156.377,
#                                 'y_rotation': 0,
#                                 'y_scaling': 1,
#                                 'y_translation': 73.048,
#                                 'z_rotation': 0,
#                                 'z_scaling': 1,
#                                 'z_translation': 83.52},
#                   'slice_count': 4,
#                   'slice_thickness': 10,
#                   'x_dimension': 10,
#                   'y_dimension': 10,
#                   'z_dimension': 10},
#  'sample_category': 'Block',
#  'sennet_id': 'SNT326.PVLT.534',
#  'source': {'created_by_user_displayname': 'Ivy Kosater',
#             'created_by_user_email': 'imk2130@cumc.columbia.edu',
#             'created_by_user_sub': '7124a15e-2abf-4fb1-9ade-fc20f879ddf7',
#             'created_timestamp': 1684247200541,
#             'data_access_level': 'consortium',
#             'description': '',
#             'entity_type': 'Source',
#             'group_name': 'TMC - Columbia University',
#             'group_uuid': '5ed4e70f-ee72-11ec-8b17-9fe9b51132b1',
#             'lab_source_id': 'U54-HRA-058',
#             'last_modified_timestamp': 1684247200541,
#             'last_modified_user_displayname': 'Ivy Kosater',
#             'last_modified_user_email': 'imk2130@cumc.columbia.edu',
#             'last_modified_user_sub': '7124a15e-2abf-4fb1-9ade-fc20f879ddf7',
#             'sennet_id': 'SNT239.DNSH.749',
#             'source_type': 'Human',
#             'uuid': '656faf3100daa4079d6bb2737fa312c6'},
#  'uuid': '27d0f1754a6eba6198990de99cd6f635'}
# {'created_by_user_displayname': 'Ivy Kosater',
#  'created_by_user_email': 'imk2130@cumc.columbia.edu',
#  'created_by_user_sub': '7124a15e-2abf-4fb1-9ade-fc20f879ddf7',
#  'created_timestamp': 1685470437534,
#  'data_access_level': 'consortium',
#  'description': 'N/A',
#  'direct_ancestor': {'created_by_user_displayname': 'Ivy Kosater',
#                      'created_by_user_email': 'imk2130@cumc.columbia.edu',
#                      'created_by_user_sub': '7124a15e-2abf-4fb1-9ade-fc20f879ddf7',
#                      'created_timestamp': 1684247200541,
#                      'data_access_level': 'consortium',
#                      'entity_type': 'Source',
#                      'group_name': 'TMC - Columbia University',
#                      'group_uuid': '5ed4e70f-ee72-11ec-8b17-9fe9b51132b1',
#                      'lab_source_id': 'U54-HRA-058',
#                      'last_modified_timestamp': 1684247200541,
#                      'last_modified_user_displayname': 'Ivy Kosater',
#                      'last_modified_user_email': 'imk2130@cumc.columbia.edu',
#                      'last_modified_user_sub': '7124a15e-2abf-4fb1-9ade-fc20f879ddf7',
#                      'sennet_id': 'SNT239.DNSH.749',
#                      'source_type': 'Human',
#                      'uuid': '656faf3100daa4079d6bb2737fa312c6'},
#  'entity_type': 'Sample',
#  'group_name': 'TMC - Columbia University',
#  'group_uuid': '5ed4e70f-ee72-11ec-8b17-9fe9b51132b1',
#  'lab_tissue_sample_id': 'U54-HRA-058',
#  'last_modified_timestamp': 1685470437534,
#  'last_modified_user_displayname': 'Ivy Kosater',
#  'last_modified_user_email': 'imk2130@cumc.columbia.edu',
#  'last_modified_user_sub': '7124a15e-2abf-4fb1-9ade-fc20f879ddf7',
#  'organ': 'BR',
#  'protocol_url': 'dx.doi.org/10.17504/protocols.io.3byl4j398lo5',
#  'sample_category': 'Organ',
#  'sennet_id': 'SNT686.CXXH.355',
#  'source': {'created_by_user_displayname': 'Ivy Kosater',
#             'created_by_user_email': 'imk2130@cumc.columbia.edu',
#             'created_by_user_sub': '7124a15e-2abf-4fb1-9ade-fc20f879ddf7',
#             'created_timestamp': 1684247200541,
#             'data_access_level': 'consortium',
#             'description': '',
#             'entity_type': 'Source',
#             'group_name': 'TMC - Columbia University',
#             'group_uuid': '5ed4e70f-ee72-11ec-8b17-9fe9b51132b1',
#             'lab_source_id': 'U54-HRA-058',
#             'last_modified_timestamp': 1684247200541,
#             'last_modified_user_displayname': 'Ivy Kosater',
#             'last_modified_user_email': 'imk2130@cumc.columbia.edu',
#             'last_modified_user_sub': '7124a15e-2abf-4fb1-9ade-fc20f879ddf7',
#             'sennet_id': 'SNT239.DNSH.749',
#             'source_type': 'Human',
#             'uuid': '656faf3100daa4079d6bb2737fa312c6'},
#  'uuid': '87f690b8368e8dbfc4ed436adb1c71a9'}

# %%
# get ancestors for sample to get RUI location
extraction_sites = []

for i in samples:
  ancestors_dict = call_entity_api(ancestors, i['uuid'])
  if "rui_location" in ancestors_dict:
    extraction_sites.append(ancestors_dict['rui_location'])
    
for e in extraction_sites:
  pprint(e)
# Out:
# {'@context': 'https://hubmapconsortium.github.io/ccf-ontology/ccf-context.jsonld',
#  '@id': 'http://purl.org/ccf/1.5/e4a5c9bd-d9b2-4f63-92b1-820bfc1c01d2',
#  '@type': 'SpatialEntity',
#  'ccf_annotations': ['http://purl.obolibrary.org/obo/UBERON_0002702'],
#  'creation_date': '2024-04-08',
#  'creator': 'Courteney Mattison',
#  'creator_first_name': 'Courteney',
#  'creator_last_name': 'Mattison',
#  'dimension_units': 'millimeter',
#  'placement': {'@context': 'https://hubmapconsortium.github.io/ccf-ontology/ccf-context.jsonld',
#                '@id': 'http://purl.org/ccf/1.5/e4a5c9bd-d9b2-4f63-92b1-820bfc1c01d2_placement',
#                '@type': 'SpatialPlacement',
#                'placement_date': '2024-04-08',
#                'rotation_order': 'XYZ',
#                'rotation_units': 'degree',
#                'scaling_units': 'ratio',
#                'target': 'http://purl.org/ccf/latest/ccf.owl#VHMAllenBrain',
#                'translation_units': 'millimeter',
#                'x_rotation': 0,
#                'x_scaling': 1,
#                'x_translation': 156.377,
#                'y_rotation': 0,
#                'y_scaling': 1,
#                'y_translation': 73.048,
#                'z_rotation': 0,
#                'z_scaling': 1,
#                'z_translation': 83.52},
#  'slice_count': 4,
#  'slice_thickness': 10,
#  'x_dimension': 10,
#  'y_dimension': 10,
#  'z_dimension': 10}

# %%
# Visualize extraction site with EUI widget
eui = Eui()
display(eui)
# Out:
# Eui(data_sources=['https://purl.humanatlas.io/collection/ds-graphs'], filter=None, header=False, height='1000p…
